# %%
import pandas as pd
import matplotlib.pyplot as plt



df=pd.read_csv("students_scores.csv")
print(df.head)

df_cleaned = df[df[ "math_score"] >= 0]

plt.figure(figsize=(20,5))

plt.bar(df["name"],df["science_score"],alpha=0.4)
plt.xlabel("name")
plt.ylabel("science_score")
plt.show()
# Out:
# <bound method NDFrame.head of    student_id    name  math_score  science_score  english_score
# 0           1     Ali          85             80             82
# 1           2    Sara          92             95             89
# 2           3    Omar          78             75             80
# 3           4    Lina          90             88             91
# 4           5  Yousef          88             90             87>
